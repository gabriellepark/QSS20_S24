# %% [markdown]
# ## Problem Set 2: Merging and regular expressions
#
# **Total points (without extra credit)**: 30
#
# **Background on the policy context**: here, we're going to use two datasets to practice reshaping, merging, and regular expression patterns. Both datasets relate to the broader issue of which employers might be violating the rights of temporary guestworkers granted visas under the H-2A program. Here are some articles about potential exploitation of guestworkers by firms and inequality caused by minimal oversight:
#
# - News media coverage of labor abuses of temporary guestworkers: https://www.buzzfeednews.com/article/kenbensinger/the-pushovers
# - GAO report on labor abuses of temporary guestworkers: https://www.gao.gov/products/gao-15-154
#
# The following datasets are located in `pset2_inputdata` (need to unzip):
#
# - `jobs_clean`: a dataset of guestworker jobs posted by many employers, some of whom have been debarred (banned) from the program for labor abuses; others not debarred
# - `debar`: a dataset of employers who committed violations of labor regulations meant to protect temporary guestworkers
#
#
# You can view a codebook here: https://docs.google.com/spreadsheets/d/1rF9GJEC8pPKxipD0TsoG9DVdqz3EJ-b-BHEtyioAX7I/edit?usp=sharing

# %%
## helpful packages
import pandas as pd
import numpy as np
import random
import re
import os

## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 1. Reshaping data (13 points total)

# %% [markdown]
# Load the following dataset stored in `pset2_inputdata`: `debar.csv`
#
# This represents employers temporarily banned from hiring workers (debar.csv); call this `debar`
#
#
# View the head()

# %%
## your code here

debar = pd.read_csv("pset2_inputdata/debar.csv")

debar.head()
# Out:
#                                Name     City, State  \
# 0                    J&J Harvesting       Leads, ND
# 1            Stahlman Apiaries, Inc       Selby, SD
# 2                     Trust Nursery     Pulaski, NY
# 3             Anton Fertilizer Inc.     Dighton, KS
# 4  Great Plains Fluid Service, Inc.  Greensburg, KS
#
#                                         Violation Duration Start date  \
# 0  Failure to respond to audit (partial response)  2 years  1/19/2014
# 1  Failure to respond to audit (partial response)   1 year  2/19/2015
# 2  Failure to respond to audit (partial response)   1 year  3/21/2014
# 3       Failure to respond to audit (no response)  2 years  3/30/2014
# 4       Failure to respond to audit (no response)  2 years  3/30/2014
#
#     End date
# 0  1/18/2016
# 1  2/14/2016
# 2  3/20/2015
# 3  3/29/2016
# 4  3/29/2016

# %% [markdown]
# ## 1.1 (1 point)
#
# Print the number of rows in `debar` versus the number of unique employer names (`Name`). Is there one row per employer or multiple rows for some employers?

# %%
## your code here

debar.shape[0]

debar.Name.nunique()
# Out:
# 114
# 98

# %% [markdown]
# There are multiple rows for some employers.

# %% [markdown]
# ## 1.2 Investigating duplicated rows (2 points)
#
# A. Create a new column in `debar`--`is_repeated`-- that tells us whether an employer (`Name`) is repeated > 1 times
#
# *Hint*: there are multiple ways to solve this but some possibilities to get the list of names that are repeated are:
# - Using value_counts() on the `Name` variable and extracting the index from that value counts
# - Using groupby to count the rows attached to one name
#
# B. Print the rows where `is_repeated == True` and interpret
#
# C. Subset to the rows where `is_repeated == True` and save that data as `mult_debar`. Print the head() and shape

# %%
name_counts = debar['Name'].value_counts() > 1
name_counts
# Out:
# Name
# Maple Ridge Custom Services, LLC            True
# Loewen Harvesting LLC                       True
# Old Tree Farms/Verpaalen Custom Service     True
# Dove Creek Farms                            True
# Cisco Produce Inc.                          True
#                                            ...
# Glenda Harrod Farms                        False
# Chris Robinson                             False
# Haiti/USA Workforce, LLC                   False
# Leonard Smith Farms                        False
# Delia Rojas                                False
# Name: count, Length: 98, dtype: bool

# %%
## your code here
debar['is_repeated'] = debar['Name'].isin(name_counts[name_counts == True].index)

# %%
debar[debar['is_repeated'] == True].sort_values('Name')
# Out:
#                                         Name       City, State  \
# 6                    Annabella Land & Cattle     Annabella, UT
# 30                   Annabella Land & Cattle   Annabella, Utah
# 29                       Autumn Hill Orchard        Groton, MA
# 7                        Autumn Hill Orchard        Groton, MA
# 8      Caddo Creek Ranch, dba Paradise Ranch         Caddo, TX
# 28     Caddo Creek Ranch, dba Paradise Ranch      Caddo, Texas
# 56                        Cisco Produce Inc.         Cairo, GA
# 19                        Cisco Produce Inc.         Cairo, GA
# 103                         Dove Creek Farms  Mount Vernon, TX
# 109                         Dove Creek Farms  Mount Vernon, TX
# 58                                 F&W Farms       Ingalls, KS
# 18                                 F&W Farms       Ingalls, KS
# 11                     Loewen Harvesting LLC   Brownsville, TX
# 25                     Loewen Harvesting LLC    Brownfield, TX
# 55                      Macky and Brad Farms        Plains, TX
# 31                      Macky and Brad Farms        Plains, TX
# 17          Maple Ridge Custom Services, LLC     Altheimer, AK
# 59          Maple Ridge Custom Services, LLC     Altheimer, AR
# 16                               Mark Duncan     Roosevelt, UT
# 60                               Mark Duncan     Roosevelt, UT
# 21   Old Tree Farms/Verpaalen Custom Service         Volga, SD
# 51   Old Tree Farms/Verpaalen Custom Service         Volga, SD
# 12               Rollo Farm Labor Contractor         Miami, FL
# 24               Rollo Farm Labor Contractor         Miami, FL
# 15                                 SRT Farms        Morton, TX
# 61                                 SRT Farms        Morton, TX
# 14                             Sharon Mathis        Tifton, GA
# 62                             Sharon Mathis        Tifton, GA
# 106                             Turner Farms         Healy, KS
# 111                             Turner Farms         Healy, KS
# 73                              Xavier Horne    Lyons, Georgia
# 89                              Xavier Horne    Lyons, Georgia
#
#                                              Violation  Duration  Start date  \
# 6                                          Non Payment    1 year    5/9/2014
# 30                                         Non-payment    1 year    5/9/2014
# 29          Impeding the Audit Process – Non- Response   2 years    7/6/2014
# 7            Failure to respond to audit (no response)   2 years    7/6/2014
# 8       Failure to respond to audit (partial response)   2 years   7/20/2014
# 28      Impeding the Audit Process – Partial- Response   2 years   7/20/2014
# 56          Impeding the Audit Process – Non- Response   2 years  12/10/2015
# 19           Failure to respond to audit (no response)   2 years  12/10/2014
# 103                Failure to respond to audit request   2 years    2/9/2018
# 109                Failure to Respond to Audit Request   2 years    2/9/2018
# 58      Impeding the Audit Process – Partial- Response    1 year  12/10/2014
# 18      Failure to respond to audit (partial response)   2 years  12/10/2014
# 11      Failure to respond to audit (partial response)    1 year   8/20/2014
# 25      Impeding the Audit Process – Partial- Response    1 year   8/20/2014
# 55      Impeding the Audit Process – Partial- Response    1 year   2/13/2015
# 31           Failure to respond to audit (no response)    1 year   2/13/2015
# 17      Failure to respond to audit (partial response)   2 years  11/16/2014
# 59      Impeding the Audit Process – Partial- Response    1 year  11/16/2014
# 16           Failure to respond to audit (no response)   2 years  11/16/2014
# 60          Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 21                                       WHD Debarment   3 years  12/11/2014
# 51                                 Wage Hour Debarment   3 years   12/1/2014
# 12           Failure to respond to audit (no response)   2 years   8/23/2014
# 24          Impeding the Audit Process – Non- Response   2 years   8/23/2014
# 15           Failure to respond to audit (no response)   2 years  11/16/2014
# 61          Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 14           Failure to respond to audit (no response)   2 years  11/16/2014
# 62          Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 106  Failure to comply with the employer's obligati...  6 months     7/17/19
# 111  Failure to comply with the employer's obligati...  7 months     7/17/19
# 73                    Non-payment of certification fee    1 year   6/16/2016
# 89                 Failure to respond to audit request   2 years   9/27/2017
#
#        End date  is_repeated
# 6      5/9/2015         True
# 30     5/8/2015         True
# 29     7/5/2016         True
# 7      7/5/2016         True
# 8     7/19/2016         True
# 28    7/19/2016         True
# 56    12/9/2017         True
# 19    12/9/2016         True
# 103    2/8/2018         True
# 109    2/8/2020         True
# 58    12/9/2015         True
# 18    12/9/2016         True
# 11    8/19/2015         True
# 25    8/19/2015         True
# 55    2/12/2016         True
# 31    2/12/2016         True
# 17   11/15/2016         True
# 59   11/15/2015         True
# 16   11/15/2016         True
# 60   11/15/2016         True
# 21   12/10/2017         True
# 51    12/1/2017         True
# 12    8/22/2016         True
# 24    8/22/2016         True
# 15   11/15/2016         True
# 61   11/15/2016         True
# 14   11/15/2016         True
# 62   11/15/2016         True
# 106   2/10/2020         True
# 111     2/10/20         True
# 73    6/15/2017         True
# 89    9/26/2019         True

# %% [markdown]
# either across multiple years, two charges for same thing, diff place etc.

# %%
mult_debar = debar[debar['is_repeated'] == True]
mult_debar.head()
mult_debar.shape
# Out:
#                                      Name      City, State  \
# 6                 Annabella Land & Cattle    Annabella, UT
# 7                     Autumn Hill Orchard       Groton, MA
# 8   Caddo Creek Ranch, dba Paradise Ranch        Caddo, TX
# 11                  Loewen Harvesting LLC  Brownsville, TX
# 12            Rollo Farm Labor Contractor        Miami, FL
#
#                                          Violation Duration Start date  \
# 6                                      Non Payment   1 year   5/9/2014
# 7        Failure to respond to audit (no response)  2 years   7/6/2014
# 8   Failure to respond to audit (partial response)  2 years  7/20/2014
# 11  Failure to respond to audit (partial response)   1 year  8/20/2014
# 12       Failure to respond to audit (no response)  2 years  8/23/2014
#
#      End date  is_repeated
# 6    5/9/2015         True
# 7    7/5/2016         True
# 8   7/19/2016         True
# 11  8/19/2015         True
# 12  8/22/2016         True
# (32, 7)

# %% [markdown]
# ## 1.3 Reshape mult_debar to wide to begin filtering out duplicates (4 points)
#
# You want to separate out two cases:
#
# - Cases where the repeat rows for one employer are due to duplicated data
# - Cases where the repeat rows for one employer represent repeated violations for different issues
#
# There are various ways to check duplicates in this data (eg converting `Violation` to lowercase; replacing spelled-out states with two-dig state codes)
#
# We're going to use the simple rule of:
#
# - A row is a duplicate if, within an employer (defined by Name + City, State), the Start date for each row's violation is the same
#
# To begin to check this, reshape `mult_debar` to a wide dataframe (`mult_debar_wide`) with the following columns, treating the `Name` and `City, State` as the index for the pivot:
#
# - Name
# - City, State
# - start_date_viol1
# - start_date_viol2
#
# Print the head and shape

# %%
mult_debar.sort_values('Name')
# Out:
#                                         Name       City, State  \
# 6                    Annabella Land & Cattle     Annabella, UT
# 30                   Annabella Land & Cattle   Annabella, Utah
# 29                       Autumn Hill Orchard        Groton, MA
# 7                        Autumn Hill Orchard        Groton, MA
# 8      Caddo Creek Ranch, dba Paradise Ranch         Caddo, TX
# 28     Caddo Creek Ranch, dba Paradise Ranch      Caddo, Texas
# 56                        Cisco Produce Inc.         Cairo, GA
# 19                        Cisco Produce Inc.         Cairo, GA
# 103                         Dove Creek Farms  Mount Vernon, TX
# 109                         Dove Creek Farms  Mount Vernon, TX
# 58                                 F&W Farms       Ingalls, KS
# 18                                 F&W Farms       Ingalls, KS
# 11                     Loewen Harvesting LLC   Brownsville, TX
# 25                     Loewen Harvesting LLC    Brownfield, TX
# 55                      Macky and Brad Farms        Plains, TX
# 31                      Macky and Brad Farms        Plains, TX
# 17          Maple Ridge Custom Services, LLC     Altheimer, AK
# 59          Maple Ridge Custom Services, LLC     Altheimer, AR
# 16                               Mark Duncan     Roosevelt, UT
# 60                               Mark Duncan     Roosevelt, UT
# 21   Old Tree Farms/Verpaalen Custom Service         Volga, SD
# 51   Old Tree Farms/Verpaalen Custom Service         Volga, SD
# 12               Rollo Farm Labor Contractor         Miami, FL
# 24               Rollo Farm Labor Contractor         Miami, FL
# 15                                 SRT Farms        Morton, TX
# 61                                 SRT Farms        Morton, TX
# 14                             Sharon Mathis        Tifton, GA
# 62                             Sharon Mathis        Tifton, GA
# 106                             Turner Farms         Healy, KS
# 111                             Turner Farms         Healy, KS
# 73                              Xavier Horne    Lyons, Georgia
# 89                              Xavier Horne    Lyons, Georgia
#
#                                              Violation  Duration  Start date  \
# 6                                          Non Payment    1 year    5/9/2014
# 30                                         Non-payment    1 year    5/9/2014
# 29          Impeding the Audit Process – Non- Response   2 years    7/6/2014
# 7            Failure to respond to audit (no response)   2 years    7/6/2014
# 8       Failure to respond to audit (partial response)   2 years   7/20/2014
# 28      Impeding the Audit Process – Partial- Response   2 years   7/20/2014
# 56          Impeding the Audit Process – Non- Response   2 years  12/10/2015
# 19           Failure to respond to audit (no response)   2 years  12/10/2014
# 103                Failure to respond to audit request   2 years    2/9/2018
# 109                Failure to Respond to Audit Request   2 years    2/9/2018
# 58      Impeding the Audit Process – Partial- Response    1 year  12/10/2014
# 18      Failure to respond to audit (partial response)   2 years  12/10/2014
# 11      Failure to respond to audit (partial response)    1 year   8/20/2014
# 25      Impeding the Audit Process – Partial- Response    1 year   8/20/2014
# 55      Impeding the Audit Process – Partial- Response    1 year   2/13/2015
# 31           Failure to respond to audit (no response)    1 year   2/13/2015
# 17      Failure to respond to audit (partial response)   2 years  11/16/2014
# 59      Impeding the Audit Process – Partial- Response    1 year  11/16/2014
# 16           Failure to respond to audit (no response)   2 years  11/16/2014
# 60          Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 21                                       WHD Debarment   3 years  12/11/2014
# 51                                 Wage Hour Debarment   3 years   12/1/2014
# 12           Failure to respond to audit (no response)   2 years   8/23/2014
# 24          Impeding the Audit Process – Non- Response   2 years   8/23/2014
# 15           Failure to respond to audit (no response)   2 years  11/16/2014
# 61          Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 14           Failure to respond to audit (no response)   2 years  11/16/2014
# 62          Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 106  Failure to comply with the employer's obligati...  6 months     7/17/19
# 111  Failure to comply with the employer's obligati...  7 months     7/17/19
# 73                    Non-payment of certification fee    1 year   6/16/2016
# 89                 Failure to respond to audit request   2 years   9/27/2017
#
#        End date  is_repeated
# 6      5/9/2015         True
# 30     5/8/2015         True
# 29     7/5/2016         True
# 7      7/5/2016         True
# 8     7/19/2016         True
# 28    7/19/2016         True
# 56    12/9/2017         True
# 19    12/9/2016         True
# 103    2/8/2018         True
# 109    2/8/2020         True
# 58    12/9/2015         True
# 18    12/9/2016         True
# 11    8/19/2015         True
# 25    8/19/2015         True
# 55    2/12/2016         True
# 31    2/12/2016         True
# 17   11/15/2016         True
# 59   11/15/2015         True
# 16   11/15/2016         True
# 60   11/15/2016         True
# 21   12/10/2017         True
# 51    12/1/2017         True
# 12    8/22/2016         True
# 24    8/22/2016         True
# 15   11/15/2016         True
# 61   11/15/2016         True
# 14   11/15/2016         True
# 62   11/15/2016         True
# 106   2/10/2020         True
# 111     2/10/20         True
# 73    6/15/2017         True
# 89    9/26/2019         True

# %%
df_duplicate = df.copy()
df_duplicate['Start date duplicate'] = df_duplicate['Start date']

# %%
mult_debar_duplicate = mult_debar.copy()

# %%
mult_debar_duplicate['Start date duplicate'] = mult_debar_duplicate['Start date']
mult_debar_duplicate
# Out:
#                                         Name       City, State  \
# 6                    Annabella Land & Cattle     Annabella, UT
# 7                        Autumn Hill Orchard        Groton, MA
# 8      Caddo Creek Ranch, dba Paradise Ranch         Caddo, TX
# 11                     Loewen Harvesting LLC   Brownsville, TX
# 12               Rollo Farm Labor Contractor         Miami, FL
# 14                             Sharon Mathis        Tifton, GA
# 15                                 SRT Farms        Morton, TX
# 16                               Mark Duncan     Roosevelt, UT
# 17          Maple Ridge Custom Services, LLC     Altheimer, AK
# 18                                 F&W Farms       Ingalls, KS
# 19                        Cisco Produce Inc.         Cairo, GA
# 21   Old Tree Farms/Verpaalen Custom Service         Volga, SD
# 24               Rollo Farm Labor Contractor         Miami, FL
# 25                     Loewen Harvesting LLC    Brownfield, TX
# 28     Caddo Creek Ranch, dba Paradise Ranch      Caddo, Texas
# 29                       Autumn Hill Orchard        Groton, MA
# 30                   Annabella Land & Cattle   Annabella, Utah
# 31                      Macky and Brad Farms        Plains, TX
# 51   Old Tree Farms/Verpaalen Custom Service         Volga, SD
# 55                      Macky and Brad Farms        Plains, TX
# 56                        Cisco Produce Inc.         Cairo, GA
# 58                                 F&W Farms       Ingalls, KS
# 59          Maple Ridge Custom Services, LLC     Altheimer, AR
# 60                               Mark Duncan     Roosevelt, UT
# 61                                 SRT Farms        Morton, TX
# 62                             Sharon Mathis        Tifton, GA
# 73                              Xavier Horne    Lyons, Georgia
# 89                              Xavier Horne    Lyons, Georgia
# 103                         Dove Creek Farms  Mount Vernon, TX
# 106                             Turner Farms         Healy, KS
# 109                         Dove Creek Farms  Mount Vernon, TX
# 111                             Turner Farms         Healy, KS
#
#                                              Violation  Duration  Start date  \
# 6                                          Non Payment    1 year    5/9/2014
# 7            Failure to respond to audit (no response)   2 years    7/6/2014
# 8       Failure to respond to audit (partial response)   2 years   7/20/2014
# 11      Failure to respond to audit (partial response)    1 year   8/20/2014
# 12           Failure to respond to audit (no response)   2 years   8/23/2014
# 14           Failure to respond to audit (no response)   2 years  11/16/2014
# 15           Failure to respond to audit (no response)   2 years  11/16/2014
# 16           Failure to respond to audit (no response)   2 years  11/16/2014
# 17      Failure to respond to audit (partial response)   2 years  11/16/2014
# 18      Failure to respond to audit (partial response)   2 years  12/10/2014
# 19           Failure to respond to audit (no response)   2 years  12/10/2014
# 21                                       WHD Debarment   3 years  12/11/2014
# 24          Impeding the Audit Process – Non- Response   2 years   8/23/2014
# 25      Impeding the Audit Process – Partial- Response    1 year   8/20/2014
# 28      Impeding the Audit Process – Partial- Response   2 years   7/20/2014
# 29          Impeding the Audit Process – Non- Response   2 years    7/6/2014
# 30                                         Non-payment    1 year    5/9/2014
# 31           Failure to respond to audit (no response)    1 year   2/13/2015
# 51                                 Wage Hour Debarment   3 years   12/1/2014
# 55      Impeding the Audit Process – Partial- Response    1 year   2/13/2015
# 56          Impeding the Audit Process – Non- Response   2 years  12/10/2015
# 58      Impeding the Audit Process – Partial- Response    1 year  12/10/2014
# 59      Impeding the Audit Process – Partial- Response    1 year  11/16/2014
# 60          Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 61          Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 62          Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 73                    Non-payment of certification fee    1 year   6/16/2016
# 89                 Failure to respond to audit request   2 years   9/27/2017
# 103                Failure to respond to audit request   2 years    2/9/2018
# 106  Failure to comply with the employer's obligati...  6 months     7/17/19
# 109                Failure to Respond to Audit Request   2 years    2/9/2018
# 111  Failure to comply with the employer's obligati...  7 months     7/17/19
#
#        End date  is_repeated Start date duplicate
# 6      5/9/2015         True             5/9/2014
# 7      7/5/2016         True             7/6/2014
# 8     7/19/2016         True            7/20/2014
# 11    8/19/2015         True            8/20/2014
# 12    8/22/2016         True            8/23/2014
# 14   11/15/2016         True           11/16/2014
# 15   11/15/2016         True           11/16/2014
# 16   11/15/2016         True           11/16/2014
# 17   11/15/2016         True           11/16/2014
# 18    12/9/2016         True           12/10/2014
# 19    12/9/2016         True           12/10/2014
# 21   12/10/2017         True           12/11/2014
# 24    8/22/2016         True            8/23/2014
# 25    8/19/2015         True            8/20/2014
# 28    7/19/2016         True            7/20/2014
# 29     7/5/2016         True             7/6/2014
# 30     5/8/2015         True             5/9/2014
# 31    2/12/2016         True            2/13/2015
# 51    12/1/2017         True            12/1/2014
# 55    2/12/2016         True            2/13/2015
# 56    12/9/2017         True           12/10/2015
# 58    12/9/2015         True           12/10/2014
# 59   11/15/2015         True           11/16/2014
# 60   11/15/2016         True           11/16/2014
# 61   11/15/2016         True           11/16/2014
# 62   11/15/2016         True           11/16/2014
# 73    6/15/2017         True            6/16/2016
# 89    9/26/2019         True            9/27/2017
# 103    2/8/2018         True             2/9/2018
# 106   2/10/2020         True              7/17/19
# 109    2/8/2020         True             2/9/2018
# 111     2/10/20         True              7/17/19

# %%
def get_first_and_second_dates(dates):
    return pd.Series({'start_date_viol1': dates.iloc[0], 'start_date_viol2': dates.iloc[1] if len(dates) > 1 else None})

# %%
mult_debar_wide = mult_debar.pivot_table(values = "Start date", index = ['Name', 'City, State'],  aggfunc=get_first_and_second_dates)

# %%
mult_debar_wide = mult_debar_duplicate.pivot_table(values = ["Start date", "Start date duplicate"], index = ['Name', 'City, State'],  aggfunc={'Start date': 'first', 'Start date duplicate': 'last'})

# %%
mult_debar_wide
# Out:
#                                                           Start date  \
# Name                                    City, State
# Annabella Land & Cattle                 Annabella, UT       5/9/2014
#                                         Annabella, Utah     5/9/2014
# Autumn Hill Orchard                     Groton, MA          7/6/2014
# Caddo Creek Ranch, dba Paradise Ranch   Caddo, TX          7/20/2014
#                                         Caddo, Texas       7/20/2014
# Cisco Produce Inc.                      Cairo, GA         12/10/2014
# Dove Creek Farms                        Mount Vernon, TX    2/9/2018
# F&W Farms                               Ingalls, KS       12/10/2014
# Loewen Harvesting LLC                   Brownfield, TX     8/20/2014
#                                         Brownsville, TX    8/20/2014
# Macky and Brad Farms                    Plains, TX         2/13/2015
# Maple Ridge Custom Services, LLC        Altheimer, AK     11/16/2014
#                                         Altheimer, AR     11/16/2014
# Mark Duncan                             Roosevelt, UT     11/16/2014
# Old Tree Farms/Verpaalen Custom Service Volga, SD         12/11/2014
# Rollo Farm Labor Contractor             Miami, FL          8/23/2014
# SRT Farms                               Morton, TX        11/16/2014
# Sharon Mathis                           Tifton, GA        11/16/2014
# Turner Farms                            Healy, KS            7/17/19
# Xavier Horne                            Lyons, Georgia     6/16/2016
#
#                                                          Start date duplicate
# Name                                    City, State
# Annabella Land & Cattle                 Annabella, UT                5/9/2014
#                                         Annabella, Utah              5/9/2014
# Autumn Hill Orchard                     Groton, MA                   7/6/2014
# Caddo Creek Ranch, dba Paradise Ranch   Caddo, TX                   7/20/2014
#                                         Caddo, Texas                7/20/2014
# Cisco Produce Inc.                      Cairo, GA                  12/10/2015
# Dove Creek Farms                        Mount Vernon, TX             2/9/2018
# F&W Farms                               Ingalls, KS                12/10/2014
# Loewen Harvesting LLC                   Brownfield, TX              8/20/2014
#                                         Brownsville, TX             8/20/2014
# Macky and Brad Farms                    Plains, TX                  2/13/2015
# Maple Ridge Custom Services, LLC        Altheimer, AK              11/16/2014
#                                         Altheimer, AR              11/16/2014
# Mark Duncan                             Roosevelt, UT              11/16/2014
# Old Tree Farms/Verpaalen Custom Service Volga, SD                   12/1/2014
# Rollo Farm Labor Contractor             Miami, FL                   8/23/2014
# SRT Farms                               Morton, TX                 11/16/2014
# Sharon Mathis                           Tifton, GA                 11/16/2014
# Turner Farms                            Healy, KS                     7/17/19
# Xavier Horne                            Lyons, Georgia              9/27/2017

# %%
mult_debar_wide[['start_date_viol1', 'start_date_viol2']] =

# %%
# Out:
# /var/folders/62/q5cwr8p541q40q2zbtg90hxh0000gn/T/ipykernel_78418/2368301786.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   split_dates = mult_debar_wide['Start date'][0]

# %%
mult_debar_wide[['start_date_viol1', 'start_date_viol2']] = mult_debar_wide['Start date'].str.split(', ', expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 mult_debar_wide[['start_date_viol1', 'start_date_viol2']] = mult_debar_wide['Start date'].str.split(', ', expand=True)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4079, in DataFrame.__setitem__(self, key, value)
#    4077     self._setitem_frame(key, value)
#    4078 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4079     self._setitem_array(key, value)
#    4080 elif isinstance(value, DataFrame):
#    4081     self._set_item_frame_value(key, value)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4121, in DataFrame._setitem_array(self, key, value)
#    4116 else:
#    4117     # Note: unlike self.iloc[:, indexer] = value, this will
#    4118     #  never try to overwrite values inplace
#    4120     if isinstance(value, DataFrame):
# -> 4121         check_key_length(self.columns, key, value)
#    4122         for k1, k2 in zip(key, value.columns):
#    4123             self[k1] = value[k2]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexers/utils.py:390, in check_key_length(columns, key, value)
#     388 if columns.is_unique:
#     389     if len(value.columns) != len(key):
# --> 390         raise ValueError("Columns must be same length as key")
#     391 else:
#     392     # Missing keys in columns are represented as -1
#     393     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key

# %%
## your code here
mult_debar_wide = mult_debar.reset_index().pivot(index = ['Name', 'City, State'], columns = 'Violation', values ='Start date')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 2
#       1 ## your code here
# ----> 2 mult_debar_wide = mult_debar.reset_index().pivot(index = ['Name', 'City, State'], columns = 'Violation', values ='Start date')
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:9025, in DataFrame.pivot(self, columns, index, values)
#    9018 @Substitution("")
#    9019 @Appender(_shared_docs["pivot"])
#    9020 def pivot(
#    9021     self, *, columns, index=lib.no_default, values=lib.no_default
#    9022 ) -> DataFrame:
#    9023     from pandas.core.reshape.pivot import pivot
# -> 9025     return pivot(self, index=index, columns=columns, values=values)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/pivot.py:553, in pivot(data, columns, index, values)
#     549         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     550 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     551 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     552 # "Hashable"
# --> 553 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     554 result.index.names = [
#     555     name if name is not lib.no_default else None for name in result.index.names
#     556 ]
#     558 return result
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4459, in Series.unstack(self, level, fill_value, sort)
#    4414 """
#    4415 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4416
#    (...)
#    4455 b    2    4
#    4456 """
#    4457 from pandas.core.reshape.reshape import unstack
# -> 4459 return unstack(self, level, fill_value, sort)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/reshape.py:517, in unstack(obj, level, fill_value, sort)
#     515 if is_1d_only_ea_dtype(obj.dtype):
#     516     return _unstack_extension_series(obj, level, fill_value, sort=sort)
# --> 517 unstacker = _Unstacker(
#     518     obj.index, level=level, constructor=obj._constructor_expanddim, sort=sort
#     519 )
#     520 return unstacker.get_result(
#     521     obj._values, value_columns=None, fill_value=fill_value
#     522 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/reshape.py:154, in _Unstacker.__init__(self, index, level, constructor, sort)
#     146 if num_cells > np.iinfo(np.int32).max:
#     147     warnings.warn(
#     148         f"The following operation may generate {num_cells} cells "
#     149         f"in the resulting pandas object.",
#     150         PerformanceWarning,
#     151         stacklevel=find_stack_level(),
#     152     )
# --> 154 self._make_selectors()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/reshape.py:210, in _Unstacker._make_selectors(self)
#     207 mask.put(selector, True)
#     209 if mask.sum() < len(self.index):
# --> 210     raise ValueError("Index contains duplicate entries, cannot reshape")
#     212 self.group_index = comp_index
#     213 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
mult_debar.reset_index()
# Out:
#     index                                     Name       City, State  \
# 0       6                  Annabella Land & Cattle     Annabella, UT
# 1       7                      Autumn Hill Orchard        Groton, MA
# 2       8    Caddo Creek Ranch, dba Paradise Ranch         Caddo, TX
# 3      11                    Loewen Harvesting LLC   Brownsville, TX
# 4      12              Rollo Farm Labor Contractor         Miami, FL
# 5      14                            Sharon Mathis        Tifton, GA
# 6      15                                SRT Farms        Morton, TX
# 7      16                              Mark Duncan     Roosevelt, UT
# 8      17         Maple Ridge Custom Services, LLC     Altheimer, AK
# 9      18                                F&W Farms       Ingalls, KS
# 10     19                       Cisco Produce Inc.         Cairo, GA
# 11     21  Old Tree Farms/Verpaalen Custom Service         Volga, SD
# 12     24              Rollo Farm Labor Contractor         Miami, FL
# 13     25                    Loewen Harvesting LLC    Brownfield, TX
# 14     28    Caddo Creek Ranch, dba Paradise Ranch      Caddo, Texas
# 15     29                      Autumn Hill Orchard        Groton, MA
# 16     30                  Annabella Land & Cattle   Annabella, Utah
# 17     31                     Macky and Brad Farms        Plains, TX
# 18     51  Old Tree Farms/Verpaalen Custom Service         Volga, SD
# 19     55                     Macky and Brad Farms        Plains, TX
# 20     56                       Cisco Produce Inc.         Cairo, GA
# 21     58                                F&W Farms       Ingalls, KS
# 22     59         Maple Ridge Custom Services, LLC     Altheimer, AR
# 23     60                              Mark Duncan     Roosevelt, UT
# 24     61                                SRT Farms        Morton, TX
# 25     62                            Sharon Mathis        Tifton, GA
# 26     73                             Xavier Horne    Lyons, Georgia
# 27     89                             Xavier Horne    Lyons, Georgia
# 28    103                         Dove Creek Farms  Mount Vernon, TX
# 29    106                             Turner Farms         Healy, KS
# 30    109                         Dove Creek Farms  Mount Vernon, TX
# 31    111                             Turner Farms         Healy, KS
#
#                                             Violation  Duration  Start date  \
# 0                                         Non Payment    1 year    5/9/2014
# 1           Failure to respond to audit (no response)   2 years    7/6/2014
# 2      Failure to respond to audit (partial response)   2 years   7/20/2014
# 3      Failure to respond to audit (partial response)    1 year   8/20/2014
# 4           Failure to respond to audit (no response)   2 years   8/23/2014
# 5           Failure to respond to audit (no response)   2 years  11/16/2014
# 6           Failure to respond to audit (no response)   2 years  11/16/2014
# 7           Failure to respond to audit (no response)   2 years  11/16/2014
# 8      Failure to respond to audit (partial response)   2 years  11/16/2014
# 9      Failure to respond to audit (partial response)   2 years  12/10/2014
# 10          Failure to respond to audit (no response)   2 years  12/10/2014
# 11                                      WHD Debarment   3 years  12/11/2014
# 12         Impeding the Audit Process – Non- Response   2 years   8/23/2014
# 13     Impeding the Audit Process – Partial- Response    1 year   8/20/2014
# 14     Impeding the Audit Process – Partial- Response   2 years   7/20/2014
# 15         Impeding the Audit Process – Non- Response   2 years    7/6/2014
# 16                                        Non-payment    1 year    5/9/2014
# 17          Failure to respond to audit (no response)    1 year   2/13/2015
# 18                                Wage Hour Debarment   3 years   12/1/2014
# 19     Impeding the Audit Process – Partial- Response    1 year   2/13/2015
# 20         Impeding the Audit Process – Non- Response   2 years  12/10/2015
# 21     Impeding the Audit Process – Partial- Response    1 year  12/10/2014
# 22     Impeding the Audit Process – Partial- Response    1 year  11/16/2014
# 23         Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 24         Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 25         Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 26                   Non-payment of certification fee    1 year   6/16/2016
# 27                Failure to respond to audit request   2 years   9/27/2017
# 28                Failure to respond to audit request   2 years    2/9/2018
# 29  Failure to comply with the employer's obligati...  6 months     7/17/19
# 30                Failure to Respond to Audit Request   2 years    2/9/2018
# 31  Failure to comply with the employer's obligati...  7 months     7/17/19
#
#       End date  is_repeated
# 0     5/9/2015         True
# 1     7/5/2016         True
# 2    7/19/2016         True
# 3    8/19/2015         True
# 4    8/22/2016         True
# 5   11/15/2016         True
# 6   11/15/2016         True
# 7   11/15/2016         True
# 8   11/15/2016         True
# 9    12/9/2016         True
# 10   12/9/2016         True
# 11  12/10/2017         True
# 12   8/22/2016         True
# 13   8/19/2015         True
# 14   7/19/2016         True
# 15    7/5/2016         True
# 16    5/8/2015         True
# 17   2/12/2016         True
# 18   12/1/2017         True
# 19   2/12/2016         True
# 20   12/9/2017         True
# 21   12/9/2015         True
# 22  11/15/2015         True
# 23  11/15/2016         True
# 24  11/15/2016         True
# 25  11/15/2016         True
# 26   6/15/2017         True
# 27   9/26/2019         True
# 28    2/8/2018         True
# 29   2/10/2020         True
# 30    2/8/2020         True
# 31     2/10/20         True

# %%
# Out:
#                                                                                                       Violation  \
#     Name                                    City, State
# 6   Annabella Land & Cattle                 Annabella, UT                                           Non Payment
# 30  Annabella Land & Cattle                 Annabella, Utah                                         Non-payment
# 29  Autumn Hill Orchard                     Groton, MA               Impeding the Audit Process – Non- Response
# 7   Autumn Hill Orchard                     Groton, MA                Failure to respond to audit (no response)
# 8   Caddo Creek Ranch, dba Paradise Ranch   Caddo, TX            Failure to respond to audit (partial response)
# 28  Caddo Creek Ranch, dba Paradise Ranch   Caddo, Texas         Impeding the Audit Process – Partial- Response
# 56  Cisco Produce Inc.                      Cairo, GA                Impeding the Audit Process – Non- Response
# 19  Cisco Produce Inc.                      Cairo, GA                 Failure to respond to audit (no response)
# 103 Dove Creek Farms                        Mount Vernon, TX                Failure to respond to audit request
# 109 Dove Creek Farms                        Mount Vernon, TX                Failure to Respond to Audit Request
# 58  F&W Farms                               Ingalls, KS          Impeding the Audit Process – Partial- Response
# 18  F&W Farms                               Ingalls, KS          Failure to respond to audit (partial response)
# 11  Loewen Harvesting LLC                   Brownsville, TX      Failure to respond to audit (partial response)
# 25  Loewen Harvesting LLC                   Brownfield, TX       Impeding the Audit Process – Partial- Response
# 55  Macky and Brad Farms                    Plains, TX           Impeding the Audit Process – Partial- Response
# 31  Macky and Brad Farms                    Plains, TX                Failure to respond to audit (no response)
# 17  Maple Ridge Custom Services, LLC        Altheimer, AK        Failure to respond to audit (partial response)
# 59  Maple Ridge Custom Services, LLC        Altheimer, AR        Impeding the Audit Process – Partial- Response
# 16  Mark Duncan                             Roosevelt, UT             Failure to respond to audit (no response)
# 60  Mark Duncan                             Roosevelt, UT            Impeding the Audit Process – Non- Response
# 21  Old Tree Farms/Verpaalen Custom Service Volga, SD                                             WHD Debarment
# 51  Old Tree Farms/Verpaalen Custom Service Volga, SD                                       Wage Hour Debarment
# 12  Rollo Farm Labor Contractor             Miami, FL                 Failure to respond to audit (no response)
# 24  Rollo Farm Labor Contractor             Miami, FL                Impeding the Audit Process – Non- Response
# 15  SRT Farms                               Morton, TX                Failure to respond to audit (no response)
# 61  SRT Farms                               Morton, TX               Impeding the Audit Process – Non- Response
# 14  Sharon Mathis                           Tifton, GA                Failure to respond to audit (no response)
# 62  Sharon Mathis                           Tifton, GA               Impeding the Audit Process – Non- Response
# 106 Turner Farms                            Healy, KS         Failure to comply with the employer's obligati...
# 111 Turner Farms                            Healy, KS         Failure to comply with the employer's obligati...
# 73  Xavier Horne                            Lyons, Georgia                     Non-payment of certification fee
# 89  Xavier Horne                            Lyons, Georgia                  Failure to respond to audit request
#
#                                                               Duration  \
#     Name                                    City, State
# 6   Annabella Land & Cattle                 Annabella, UT       1 year
# 30  Annabella Land & Cattle                 Annabella, Utah     1 year
# 29  Autumn Hill Orchard                     Groton, MA         2 years
# 7   Autumn Hill Orchard                     Groton, MA         2 years
# 8   Caddo Creek Ranch, dba Paradise Ranch   Caddo, TX          2 years
# 28  Caddo Creek Ranch, dba Paradise Ranch   Caddo, Texas       2 years
# 56  Cisco Produce Inc.                      Cairo, GA          2 years
# 19  Cisco Produce Inc.                      Cairo, GA          2 years
# 103 Dove Creek Farms                        Mount Vernon, TX   2 years
# 109 Dove Creek Farms                        Mount Vernon, TX   2 years
# 58  F&W Farms                               Ingalls, KS         1 year
# 18  F&W Farms                               Ingalls, KS        2 years
# 11  Loewen Harvesting LLC                   Brownsville, TX     1 year
# 25  Loewen Harvesting LLC                   Brownfield, TX      1 year
# 55  Macky and Brad Farms                    Plains, TX          1 year
# 31  Macky and Brad Farms                    Plains, TX          1 year
# 17  Maple Ridge Custom Services, LLC        Altheimer, AK      2 years
# 59  Maple Ridge Custom Services, LLC        Altheimer, AR       1 year
# 16  Mark Duncan                             Roosevelt, UT      2 years
# 60  Mark Duncan                             Roosevelt, UT      2 years
# 21  Old Tree Farms/Verpaalen Custom Service Volga, SD          3 years
# 51  Old Tree Farms/Verpaalen Custom Service Volga, SD          3 years
# 12  Rollo Farm Labor Contractor             Miami, FL          2 years
# 24  Rollo Farm Labor Contractor             Miami, FL          2 years
# 15  SRT Farms                               Morton, TX         2 years
# 61  SRT Farms                               Morton, TX         2 years
# 14  Sharon Mathis                           Tifton, GA         2 years
# 62  Sharon Mathis                           Tifton, GA         2 years
# 106 Turner Farms                            Healy, KS         6 months
# 111 Turner Farms                            Healy, KS         7 months
# 73  Xavier Horne                            Lyons, Georgia      1 year
# 89  Xavier Horne                            Lyons, Georgia     2 years
#
#                                                               Start date  \
#     Name                                    City, State
# 6   Annabella Land & Cattle                 Annabella, UT       5/9/2014
# 30  Annabella Land & Cattle                 Annabella, Utah     5/9/2014
# 29  Autumn Hill Orchard                     Groton, MA          7/6/2014
# 7   Autumn Hill Orchard                     Groton, MA          7/6/2014
# 8   Caddo Creek Ranch, dba Paradise Ranch   Caddo, TX          7/20/2014
# 28  Caddo Creek Ranch, dba Paradise Ranch   Caddo, Texas       7/20/2014
# 56  Cisco Produce Inc.                      Cairo, GA         12/10/2015
# 19  Cisco Produce Inc.                      Cairo, GA         12/10/2014
# 103 Dove Creek Farms                        Mount Vernon, TX    2/9/2018
# 109 Dove Creek Farms                        Mount Vernon, TX    2/9/2018
# 58  F&W Farms                               Ingalls, KS       12/10/2014
# 18  F&W Farms                               Ingalls, KS       12/10/2014
# 11  Loewen Harvesting LLC                   Brownsville, TX    8/20/2014
# 25  Loewen Harvesting LLC                   Brownfield, TX     8/20/2014
# 55  Macky and Brad Farms                    Plains, TX         2/13/2015
# 31  Macky and Brad Farms                    Plains, TX         2/13/2015
# 17  Maple Ridge Custom Services, LLC        Altheimer, AK     11/16/2014
# 59  Maple Ridge Custom Services, LLC        Altheimer, AR     11/16/2014
# 16  Mark Duncan                             Roosevelt, UT     11/16/2014
# 60  Mark Duncan                             Roosevelt, UT     11/16/2014
# 21  Old Tree Farms/Verpaalen Custom Service Volga, SD         12/11/2014
# 51  Old Tree Farms/Verpaalen Custom Service Volga, SD          12/1/2014
# 12  Rollo Farm Labor Contractor             Miami, FL          8/23/2014
# 24  Rollo Farm Labor Contractor             Miami, FL          8/23/2014
# 15  SRT Farms                               Morton, TX        11/16/2014
# 61  SRT Farms                               Morton, TX        11/16/2014
# 14  Sharon Mathis                           Tifton, GA        11/16/2014
# 62  Sharon Mathis                           Tifton, GA        11/16/2014
# 106 Turner Farms                            Healy, KS            7/17/19
# 111 Turner Farms                            Healy, KS            7/17/19
# 73  Xavier Horne                            Lyons, Georgia     6/16/2016
# 89  Xavier Horne                            Lyons, Georgia     9/27/2017
#
#                                                                 End date  \
#     Name                                    City, State
# 6   Annabella Land & Cattle                 Annabella, UT       5/9/2015
# 30  Annabella Land & Cattle                 Annabella, Utah     5/8/2015
# 29  Autumn Hill Orchard                     Groton, MA          7/5/2016
# 7   Autumn Hill Orchard                     Groton, MA          7/5/2016
# 8   Caddo Creek Ranch, dba Paradise Ranch   Caddo, TX          7/19/2016
# 28  Caddo Creek Ranch, dba Paradise Ranch   Caddo, Texas       7/19/2016
# 56  Cisco Produce Inc.                      Cairo, GA          12/9/2017
# 19  Cisco Produce Inc.                      Cairo, GA          12/9/2016
# 103 Dove Creek Farms                        Mount Vernon, TX    2/8/2018
# 109 Dove Creek Farms                        Mount Vernon, TX    2/8/2020
# 58  F&W Farms                               Ingalls, KS        12/9/2015
# 18  F&W Farms                               Ingalls, KS        12/9/2016
# 11  Loewen Harvesting LLC                   Brownsville, TX    8/19/2015
# 25  Loewen Harvesting LLC                   Brownfield, TX     8/19/2015
# 55  Macky and Brad Farms                    Plains, TX         2/12/2016
# 31  Macky and Brad Farms                    Plains, TX         2/12/2016
# 17  Maple Ridge Custom Services, LLC        Altheimer, AK     11/15/2016
# 59  Maple Ridge Custom Services, LLC        Altheimer, AR     11/15/2015
# 16  Mark Duncan                             Roosevelt, UT     11/15/2016
# 60  Mark Duncan                             Roosevelt, UT     11/15/2016
# 21  Old Tree Farms/Verpaalen Custom Service Volga, SD         12/10/2017
# 51  Old Tree Farms/Verpaalen Custom Service Volga, SD          12/1/2017
# 12  Rollo Farm Labor Contractor             Miami, FL          8/22/2016
# 24  Rollo Farm Labor Contractor             Miami, FL          8/22/2016
# 15  SRT Farms                               Morton, TX        11/15/2016
# 61  SRT Farms                               Morton, TX        11/15/2016
# 14  Sharon Mathis                           Tifton, GA        11/15/2016
# 62  Sharon Mathis                           Tifton, GA        11/15/2016
# 106 Turner Farms                            Healy, KS          2/10/2020
# 111 Turner Farms                            Healy, KS            2/10/20
# 73  Xavier Horne                            Lyons, Georgia     6/15/2017
# 89  Xavier Horne                            Lyons, Georgia     9/26/2019
#
#                                                               is_repeated
#     Name                                    City, State
# 6   Annabella Land & Cattle                 Annabella, UT            True
# 30  Annabella Land & Cattle                 Annabella, Utah          True
# 29  Autumn Hill Orchard                     Groton, MA               True
# 7   Autumn Hill Orchard                     Groton, MA               True
# 8   Caddo Creek Ranch, dba Paradise Ranch   Caddo, TX                True
# 28  Caddo Creek Ranch, dba Paradise Ranch   Caddo, Texas             True
# 56  Cisco Produce Inc.                      Cairo, GA                True
# 19  Cisco Produce Inc.                      Cairo, GA                True
# 103 Dove Creek Farms                        Mount Vernon, TX         True
# 109 Dove Creek Farms                        Mount Vernon, TX         True
# 58  F&W Farms                               Ingalls, KS              True
# 18  F&W Farms                               Ingalls, KS              True
# 11  Loewen Harvesting LLC                   Brownsville, TX          True
# 25  Loewen Harvesting LLC                   Brownfield, TX           True
# 55  Macky and Brad Farms                    Plains, TX               True
# 31  Macky and Brad Farms                    Plains, TX               True
# 17  Maple Ridge Custom Services, LLC        Altheimer, AK            True
# 59  Maple Ridge Custom Services, LLC        Altheimer, AR            True
# 16  Mark Duncan                             Roosevelt, UT            True
# 60  Mark Duncan                             Roosevelt, UT            True
# 21  Old Tree Farms/Verpaalen Custom Service Volga, SD                True
# 51  Old Tree Farms/Verpaalen Custom Service Volga, SD                True
# 12  Rollo Farm Labor Contractor             Miami, FL                True
# 24  Rollo Farm Labor Contractor             Miami, FL                True
# 15  SRT Farms                               Morton, TX               True
# 61  SRT Farms                               Morton, TX               True
# 14  Sharon Mathis                           Tifton, GA               True
# 62  Sharon Mathis                           Tifton, GA               True
# 106 Turner Farms                            Healy, KS                True
# 111 Turner Farms                            Healy, KS                True
# 73  Xavier Horne                            Lyons, Georgia           True
# 89  Xavier Horne                            Lyons, Georgia           True

# %% [markdown]
# ## 1.4 Filter out duplicates from original debar data (6 points)
#
# A. Using `mult_debar_wide`, add a column `is_dup` that takes value of True for cases where start_date_viol1 == start_date_viol2 marking the row as a duplicate
#
# B. Going back to the original long-format data you loaded at the beginning- `debar`
#     - For employers where `is_dup == True` as indicated by your wide-format dataframe, only keep `violnum == viol1`
#     - For all other employers (so is_dup == False and ones we didnt need to check duplicates for), keep all violnum
#     - Remove the `is_repeated` column from the `debar` data
#
# **Hint**: you can complete part B without a for loop; `pd.concat` with axis = 0 (row binding) is one way
#
# Call the resulting dataframe `debar_clean` and print the shape and # of unique employer names

# %%
## your code here

# %% [markdown]
# # 2. Merging and regex (17 points total)

# %% [markdown]
# ## 2.1 Load data on job postings
#
# The previous dataset contains a small subset of employers who faced temporary bans due to violations of H-2A program regulations
#
# Since most of the bans have expired, we're going to see which of those employers posted new H-2A jobs in the first quarter of 2021
#
# Loading the `jobs_clean.csv` data stored in `pset4_inputdata`

# %%
# your code here to load the data

# %% [markdown]
# ##  2.2 Try inner join on employer name  (2 points)
#
# - Use the `EMPLOYER_NAME` field of the `jobs` dataset
# - Use the `Name` field of the `debar_clean` dataset
#
# A. Use pd.merge with an inner join on those fields to see whether there are any exact matches.
#
# B. If there are exact matches, print the row(s) with exact matches

# %%
## your code here

# %% [markdown]
# ## 2.3 Targeted regex (10 points total)
#
# You want to see if you can increase the exact match rate with some basic cleaning of each
# of the employer name fields in each dataset

# %% [markdown]
# ### 2.3.1 Converting to upper (2 points)
#
# A. Convert the `EMPLOYER_NAME` and `Name` fields to uppercase using list comprehension rather than df.varname.str.upper() (it's fine to do a separate list comprehension line for each of the two columns)
#
# B. Print a random sample of 15 values of each result
#
# C. Assign the full vector of uppercase names back to the original data, writing over the original `EMPLOYER_NAME` and `Name` columns

# %%
## insert your code to turn into uppercase here

# %%
## insert your code for the random sample

# %%
## insert your code for assigning the uppercase names back to the data

# %% [markdown]
# ### 2.3.2 Cleaning up punctuation (4 points)
#
# You notice that INC, CO, and LLC are sometimes followed by a period (.) but sometimes not
#
# A. For each dataset, write a regex pattern using `re.sub` to remove the . but only if it's preceded by INC, LLC, or CO
#
# Make sure LLC, INC, CO remain part of the string but just without the dot
#
# B. Test the pattern on the positive and negative example we provide below and print the result. See the Github issue for examples of what to return
#
#
# **Hint**: https://stackoverflow.com/questions/7191209/python-re-sub-replace-with-matched-content

# %%
pos_example_1 = "CISCO PRODUCE INC."
pos_example_2 = "AVOYELLES HONEY CO., LLC"
neg_example = "E.V. RANCH LLP"

# %%
## insert your code here with the regex pattern for part A

## insert your code to use re.sub to apply the pattern to the test cases for part B

# %% [markdown]
# ### 2.3.3 (4 points)
#
# Use that pattern in conjunction with `re.sub` and list comprehension to clean the employer name columns in each dataset. Save the new columns as `name_clean` in each. Then, use row subsetting to (1) subset to rows that changed names and (2) for:
#
# - `debar_clean` print the `Name` and `name_clean` columns
# - `jobs` print the `EMPLOYER_NAME` and `name_clean` columns
#
# Make sure to use the uppercase versions of the variables

# %%
## your code here to clean the columns

# %%
## your code here to print the head

# %% [markdown]
# ## 2.4 More joins and more cleaning (5 points)
#
# A. Conduct another inner join between `jobs` and `debar_clean` now using the `name_clean` column; print the result. Did the cleaning result in any more employers matched between the two datasets?
#
# B. Create a new column in `debar_clean` called `name_clean_2` that uses regex to take the following name in that dataset:
#
# - `SLASH E.V. RANCH LLP` in the `debar_clean` dataset
#
# And cleans it up so that it matches with this employer in `jobs`
#
# - `SLASH EV RANCH` in the `jobs` dataset
#
# Eg a pattern to remove the dots in the EV and the space+LLP-- you can apply the pattern to all employer names in debar_clean (so don't need to worry about only applying it to that one employer)
#
#
# C. Conduct a left join using `name_clean_2` as the join column where the left hand dataframe is `jobs`; right hand dataframe is `debar_clean`, store the result as a dataframe, and print the rows where the merge indicator indicates the row was found in both dataframe
#
# **Note**: this manual cleaning process is inefficient and helps motivate why talked about fuzzy matching. Fuzzy matching could recognize that Slash EV ranch is a highly similar string to slash ev ranch llp and match them without us needing to use regex to make the strings identical.

# %%
## your code here

# %% [markdown]
# # 3. Optional extra credit 1: regex to separate companies from individuals (1 point)
#
# You notice some employers in `debar_clean` have both the name of the company and the name of individual, e.g.:
#
# COUNTY FAIR FARM (COMPANY) AND ANDREW WILLIAMSON (INDIVIDUAL)*
#
# Use the uppercase/cleaned `name_clean` in `debar_clean`
#
# A. Write a regex pattern that does the following:
#     - Captures the pattern that occurs before COMPANY if (COMPANY) is in string; so in example above, extracts COUNTY FAIR FARM
#     - Captures the pattern that occurs before INDIVIDUAL if (INDIVIDUAL) is also in string -- so in above, extracts ANDREW WILLIAMSON (so omit the "and")
#
# B. Test the pattern on `pos_example` and `neg_example`-- make sure former returns a list (if using find.all) or match object (if using re.search) with the company name and individual name separated out; make sure latter returns empty
#
# **Hints and resources**: for step A, you can either use re.search, re.match, or re.findall; don't worry about matching B&R Harvesting and Paul Cruz (Individual)
#
# - Same regex resources as above

# %%
pos_example = "COUNTY FAIR FARM (COMPANY) AND ANDREW WILLIAMSON (INDIVIDUAL)*"
neg_example = "CISCO PRODUCE INC"

## your code here to define the pattern

## your code here to apply it to the pos_example

## your code here to apply it to the negative example

# %% [markdown]
# C. Iterate over the `name_clean` column in debar and use regex to create two new columns in `debar_clean`:
#    - `co_name`: A column for company (full `name_clean` string if no match; pattern before COMPANY if one extracted)
#    - `ind_name`: A column for individual (full `name_clean` string if no match; pattern before INDIVIDUAL if one extracted)

# %%
# your code here

# %% [markdown]
#
# D. Print three columns for the rows in `debar_clean` containing the negative example and positive example described above (county fair farm and cisco produce):
#
# - `name_clean`
# - `co_name`
# - `ind_name`
# - `Violation`
#
# **Note**: as shown in the outcome there may be duplicates of the same company reflecting different violations

# %%
# your code here

# %% [markdown]
# # 4. Optional extra credit 2 (up to 3 points)
#
# - For 1 point extra credit, create a visualization with 1+ of the existing fields in either the raw `jobs` or `debar` data. We'll be showing cool visualizations in class so use your imagination! Options could include visualizing between-state or over-time variation
#
# - For 3 points extra credit instead, geocode the employer addresses in `jobs` and plot the addresses of jobs as points overlaid on top of a map of Georgia
#     - **Note**: this extra credit involves Googling since we have not yet covered spatial data.
#         - For discussion of how to geocode addresses -> lat/long, see: https://www.natasshaselvaraj.com/a-step-by-step-guide-on-geocoding-in-python/
#         - For discussion of plotting lat/long dots against a map, see this discussion of geopandas: https://towardsdatascience.com/plotting-maps-with-geopandas-428c97295a73
#     - Relevant columns include `EMPLOYER_ADDRESS_1`
#     - The geocoding might have a long runtime so feel free to implement it in a separate .py script that you submit alongside your notebook and to just read in the geocoded data

# %%
## your code here
